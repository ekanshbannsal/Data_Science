# %% [markdown]
# <a href="https://colab.research.google.com/github/ekanshbannsal/Data_Science/blob/main/Lecture03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fun_name(parameters) :
  #body of the function

# %%
def add_nums(num1,num2):
  return num1+num2

#example :
result = add_nums(3,5)
print(result)
# Out:
# 8

# %% [markdown]
# LAMBDA FUNCTION -> This function is used to create one liner functions . It avoid the use of "def" again and again .

# %%
# Lambda function declaration :->
  # lambda arguments:expression
  # can take multiple arguments but takes only one expression

# %%
add_num = lambda a,b : a+b
print(add_num(2,3))
# Out:
# 5

# %% [markdown]
# Build in method

# %%
#remove spaces             strip(remove spaces from both sides) , lstrip(left side) , rstrip(right side)
#split text                split()
#join text                 join()
#replce text               replace()
#change case.              lower(),upper(),title()
#find text                 find() find index(-1 if not found)
#check text.               startswith(),endswith()
#count values.             count()
#length                    len()
#sort chairs               sorted()

# %%
str="       HeLLo        "
print(str)
print(str.strip())
print(str.lstrip())
print(str.rstrip())
# Out:
#        HeLLo
# HeLLo
# HeLLo
#        HeLLo

# %%
str="       HeLLo mY namE IS nobita         "
print(str)
print(str.strip())
print(str.lstrip())
print(str.rstrip())
# Out:
#        HeLLo mY namE IS nobita
# HeLLo mY namE IS nobita
#        HeLLo mY namE IS nobita
# HeLLo mY namE IS nobita
#        HeLLo mY namE IS nobita

# %%
str="HeLLo mY namE IS nobita  "
print(str)
print(str.split())
# Out:
# HeLLo mY namE IS nobita
# ['HeLLo', 'mY', 'namE', 'IS', 'nobita']

# %%
letters = ["P", "Y", "T", "H", "O", "N"]
print("".join(letters))

fruits = ["Apple", "Mango", "Banana"]
print(" ".join(fruits))
# Out:
# PYTHON
# Apple Mango Banana

# %%
str="HeLLo mY namE IS Nobita"
print(str)
print(str.replace("HeLLo","Hi"))
# Out:
# HeLLo mY namE IS Nobita
# Hi mY namE IS Nobita

# %%
str="HeLLo mY namE IS Nobita"
print(str)
print(str.lower(),"-LOWERCASE")
print(str.upper(),"-UPPERCASE")
print(str.title(),"-TITLE")
print(str.capitalize(),"-CAPITALISE")
# Out:
# HeLLo mY namE IS Nobita
# hello my name is nobita -LOWERCASE
# HELLO MY NAME IS NOBITA -UPPERCASE
# Hello My Name Is Nobita -TITLE
# Hello my name is nobita -CAPITALISE

# %%
str="HeLLo mY namE IS nobita"
print(str)
print(str.find("Hello"))
print(str.find("mY"))
# Out:
# HeLLo mY namE IS nobita
# -1
# 6

# %%
str="HeLLo mY namE IS Nobita"
print(str)
print(str.startswith("HeLLo"))
print(str.startswith("Hello"))
print(str.endswith("HeLLo"))
print(str.endswith("Nobita"))
# Out:
# HeLLo mY namE IS Kavya
# True
# False
# False
# True

# %%
letters = ["P", "Y", "T", "H", "O", "N","P","Y"]
print(letters.count("P"))
# Out:
# 2

# %%
letters = ["P", "Y", "T", "H", "O", "N","P","Y"]
print(len(letters))
str="HeLLo mY namE IS Nobita"
print(len(str))
# Out:
# 8
# 23

# %%
letters = ["P", "Y", "T", "H", "O", "N","P","Y"]
print(sorted(letters))
str="HeLLo mY namE IS Kavya"
print(sorted(str))
# Out:
# ['H', 'N', 'O', 'P', 'P', 'T', 'Y', 'Y']
# [' ', ' ', ' ', ' ', 'E', 'H', 'I', 'K', 'L', 'L', 'S', 'Y', 'a', 'a', 'a', 'e', 'm', 'm', 'n', 'o', 'v', 'y']

# %%
first_name='    ekansh   '
second_name='bannsal   '
#strip
first_name=first_name.rstrip()
print(first_name)
second_name=second_name.rstrip()
print(second_name)
str2=first_name+second_name
str3=first_name+' '+second_name
print(str2)
print(str3)
# Out:
#     ekansh
# bannsal
#     ekanshbannsal
#     ekansh bannsal

# %%
s="hello world"
print(s)
print(s[7:11])
print(s[:5])

# %% [markdown]
# SETS

# %%
# Collection of unique elements
# declared within {} brackets except empty set

# %%
set1=()
# set1={} means and empty dictionary
set2={1,2,3,5,3,2,1}
print(set1)
print(set2)
# Out:
# ()
# {1, 2, 3, 5}

# %% [markdown]
# Dictionary

# %%
student = {
    "name": "Ekansh",
    "age": 18,
    "branch": "CSE"
}

print(student)
# print(student['name'])
del student["name"]
print(student)
# Out:
# {'name': 'Ekansh', 'age': 18, 'branch': 'CSE'}
# {'age': 18, 'branch': 'CSE'}
