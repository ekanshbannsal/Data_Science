# %% [markdown]
# <a href="https://colab.research.google.com/github/ekanshbannsal/Data_Science/blob/main/Lecture02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# pallindrome
s = input("enter a string ")
l = len(s)
is_pallindrome = True
for i in range (l//2) :
  if s[i] != s[l-1-i] :
    is_pallindrome = False
    break

if is_pallindrome :
  print("it is pallindrome")
else :
  print("it is not a pallindrome")

# %%
#pallindrome
s = input("enter the string ")
l = len(s)
is_pallindrome = True
#dshvbshjvhegvkuhqwov;hqhqwvcgqkhgvul/qhjwb,

# %%
#list
lst = [1,2,"hello", 'abc']
print(lst)

#append()
lst.append('world')
print(lst)

#extend()
lst.extend([1,2,3])
print(lst)

#insert(index, value)
lst.insert(2,'hi')
print(lst)

#pop()
lst.pop()
print(lst)

#remove(value)
lst.remove(1)
print(lst)

#index(value,start,stop) start,stop -> optional
print(lst.index('hello'))

#cound()
print(lst.count('abc'))



#sort()
lst2 = [7,4,8,4,9,3,1]
lst2.sort()
print(lst2)

lst3 = ['a','f','r','b','z','d']
lst3.sort()
print(lst3)


#sum , min , max , sorted
lst4 = [5,9,1,3,4,7,6,8]
print(sum(lst4))
print(min(lst4))
print(max(lst4))
sorted(lst4)

# %%
#ques1
lst2 = ['ekansh','arnav','yash']
print(lst2)

lst2.append('debojit')
print(lst2)

lst2.extend(['abhinay','aditya pathak'])
print(lst2)

lst2.insert(1,'popo')
print(lst2)

# %%
#sum , min , max , sorted
lst4 = [5,9,1,3,4,7,6,8]
print(sum(lst4))
print(sorted(lst4))
print(min(lst4))
print(max(lst4))
#last wala kud hi print ho jata hai
sorted(lst4)

# %%
#tople
tp = (1,2,33,4)
a = tuple(sorted(tp))
print(a)

#toples function

#category         function

#count value      count()
#find             index()
#size             len()
#total            sum()
#highest/lowest   max()/min()
#sort             sorted()  ---->(return list)

# %%
#adding number of two list and forming the new list

n = int(input("enter the size of list =  "))
lst1 = []

for i in range(n) :
  lst1.append(int(input()))

lst2 = []
for i in range(n) :
  lst2.append(int(input()))

lst = []
for i in range(n) :
  x = lst1[i] + lst2[i]
  lst.append(x)

print(lst)
